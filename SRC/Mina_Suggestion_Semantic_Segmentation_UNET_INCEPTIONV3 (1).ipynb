# %%
# !pip3 install -U segmentation-models
# Out:
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 7.5 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.1)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
with open('/content/drive/MyDrive/ocelot2023_v0.1.2/metadata.json') as file:
    data = json.load(file)

# %%
data

# %% [markdown]
# #Importing the Images and Masks

# %%
#Handling Data in Runtime so the original data doesn't get messed up:

import shutil

src= '/content/drive/MyDrive/ocelot2023_v0.1.2'
dest='/content/ocelot2023'

shutil.copytree(src,dest)
# Out:
# '/content/ocelot2023'

# %%
import os
import cv2
import numpy as np


#image_folder = '/content/drive/MyDrive/sa_rest/images'
#mask_folder = '/content/drive/MyDrive/sa_rest/masks'

image_folder = '/content/ocelot2023/images/train/tissue'
mask_folder = '/content/ocelot2023/annotations/train/tissue'

image_files = os.listdir(image_folder)
mask_files = os.listdir(mask_folder)

images = []
masks  = []

for filename in image_files:
    img_path = os.path.join(image_folder, filename)
    img = cv2.imread(img_path)
    images.append(img)

for filename in mask_files:
    mask_path = os.path.join(mask_folder, filename)
    mask = cv2.imread(mask_path)  # Read as grayscale
    # mask = np.expand_dims(mask, axis = -1)
    masks.append(mask)

images = np.array(images)
masks = np.array(masks)

# %% [markdown]
# #Testing if loaded and plotting

# %%
from google.colab.patches import cv2_imshow
images[10].shape, masks[10].shape
# Out:
# ((1024, 1024, 3), (1024, 1024, 3))

# %%
import matplotlib.pyplot as plt
img=images[80]
ann=masks[80]
weighted_sum = cv2.addWeighted(img, 0.4, ann*127, 0.6, 0)
plt.imshow(weighted_sum)

# %% [markdown]
# #Relabelling Classes:

# %%
import os
from PIL import Image
import numpy as np

# Directory of mask images
mask_directory = '/content/ocelot2023/annotations/train/tissue'
print(mask_directory)

mask_directory1="/content/mask_updated"
# Iterate through all mask images in the directory
for filename in os.listdir(mask_directory):
    if filename.endswith(".png"):
        # Load the mask image
        mask_image = Image.open(os.path.join(mask_directory, filename))

        # Convert the image to a numpy array for manipulation
        mask_array = np.array(mask_image)

        # Map "UNK" (255) to the background label (0) also Background (0) to 0
        mask_array[mask_array == 1] = 0 #When prediction change to 0
        mask_array[mask_array == 255] = 2 #When Prediction 255

        #Map 'Tumor (2) to 1:
        mask_array[mask_array == 2]=1 #When Prediction 170

        # Convert the modified array back to an image
        modified_image = Image.fromarray(mask_array)

        # Save the modified image with a new filename
        modified_filename = f"{filename}"
        modified_image.save(os.path.join(mask_directory1, modified_filename))
# Out:
# /content/ocelot2023/annotations/train/tissue

# %%
import os
import cv2
import numpy as np
from natsort import natsorted

image_folder = '/content/ocelot2023/images/train/tissue'
mask_folder = '/content/mask_updated'

image_files = natsorted(os.listdir(image_folder))
mask_files = natsorted(os.listdir(mask_folder))

images = []
masks = []

for filename in image_files:
    img_path = os.path.join(image_folder, filename)
    img = cv2.imread(img_path)
    images.append(img)

for filename in mask_files:
    mask_path = os.path.join(mask_folder, filename)
    mask = cv2.imread(mask_path)  # Read as grayscale
    masks.append(mask)

images = np.array(images)
masks = np.array(masks)

# %%
import matplotlib.pyplot as plt
img = images[1]
ann = masks[1]
weighted_sum = cv2.addWeighted(img, 0.4, ann, 0.6, 0)
plt.imshow(weighted_sum)
plt.show()

# %%
from google.colab.patches import cv2_imshow
images[10].shape, masks[10].shape
# Out:
# ((1024, 1024, 3), (1024, 1024, 3))

# %% [markdown]
# #Generating Slides

# %%
import numpy as np

def crop_img_msk(img, msk, size, stride):
    # this function crops an image and its corresponding mask using the sliding window technique. Size is the patch size of the sliding window and stride is the stride of the sliding window patches.
    cropped_img = []
    cropped_msk = []
    size_x = img.shape[1]
    size_y = img.shape[0]
    x = np.arange(0, size_x, stride)
    y = np.arange(0, size_y, stride)
    x = [i for i in x if i+size <= size_x]
    y = [i for i in y if i+size <= size_y]
    x.append(size_x-size)
    y.append(size_y-size)
    x = np.unique(x)
    y = np.unique(y)
    for i in x:
        for j in y:
            cropped_img.append(img[j:j+size, i:i+size])
            cropped_msk.append(msk[j:j+size, i:i+size])
    return cropped_img, cropped_msk

# %%
import cv2
import math
#from crop_img_msk import crop_img_msk
import numpy as np

def rotation(image, angleInDegrees):
    h, w = image.shape[:2]
    img_c = (w / 2, h / 2)

    rot = cv2.getRotationMatrix2D(img_c, angleInDegrees, 1)

    rad = math.radians(angleInDegrees)
    sin = math.sin(rad)
    cos = math.cos(rad)
    b_w = int((h * abs(sin)) + (w * abs(cos)))
    b_h = int((h * abs(cos)) + (w * abs(sin)))

    rot[0, 2] += ((b_w / 2) - img_c[0])
    rot[1, 2] += ((b_h / 2) - img_c[1])

    outImg = cv2.warpAffine(image, rot, (b_w, b_h), flags=cv2.INTER_LINEAR)
    return outImg

def extract_patches_with_angle(img, msk, size, stride, angle):

    img_rotated = rotation(img, angle)
    msk_rotated = rotation(msk, angle)

    imgs, msks = crop_img_msk(img_rotated, msk_rotated, size, stride)

    idx = [i for i in range(len(msks)) if np.any(msks[i]==0)]

    imgs_wanted = []
    msks_wanted = []
    for i in range(len(imgs)):
        if i not in idx:
            imgs_wanted.append(imgs[i])
            msks_wanted.append(msks[i])

    return imgs_wanted, msks_wanted

# %% [markdown]
# #Augmenting Masks

# %%
import numpy as np

def aug_imgs_msks_d4(patches, patches_masks):
    # This function augments patches and masks using D4 symmetry of a square.
    # Inputs: patches and patches_masks are lists containing patches and patches_masks.
    # Outputs: aug_patches and aug_patches_masks: are lists containing the augmented patches and masks using D4 symmetry of a sqaure.

    aug_patches = []
    aug_patches_masks = []
    for i in range(len(patches)):
        aug_patches.append(patches[i])
        aug_patches_masks.append(patches_masks[i])

    for i in range(len(patches)):
        aug_patches.append(np.fliplr(patches[i]))
        aug_patches_masks.append(np.fliplr(patches_masks[i]))

    for i in range(len(patches)):
        aug_patches.append(np.flipud(patches[i]))
        aug_patches_masks.append(np.flipud(patches_masks[i]))

    for i in range(len(patches)):
        aug_patches.append(np.rot90(patches[i]))
        aug_patches_masks.append(np.rot90(patches_masks[i]))

    for i in range(len(patches)):
        aug_patches.append(np.rot90(np.rot90(patches[i])))
        aug_patches_masks.append(np.rot90(np.rot90(patches_masks[i])))

    for i in range(len(patches)):
        aug_patches.append(np.rot90(np.rot90(np.rot90(patches[i]))))
        aug_patches_masks.append(np.rot90(np.rot90(np.rot90(patches_masks[i]))))

    for i in range(len(patches)):
        aug_patches.append(np.fliplr(np.rot90(patches[i])))
        aug_patches_masks.append(np.fliplr(np.rot90(patches_masks[i])))

    for i in range(len(patches)):
        aug_patches.append(np.flipud(np.rot90(patches[i])))
        aug_patches_masks.append(np.flipud(np.rot90(patches_masks[i])))

    return aug_patches, aug_patches_masks

# %% [markdown]
# #Segmentation Architecture - UNEt with Inception V3

# %%
# !pip install -U -q segmentation-models
# !pip install -q tensorflow==2.2.1
# !pip install -q keras==2.5
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

from tensorflow import keras
import segmentation_models as sm
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.2.1 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2)
# ERROR: No matching distribution found for tensorflow==2.2.1
# ERROR: Could not find a version that satisfies the requirement keras==2.5 (from versions: 0.2.0, 0.3.0, 0.3.1, 0.3.2, 0.3.3, 1.0.0, 1.0.1, 1.0.2, 1.0.3, 1.0.4, 1.0.5, 1.0.6, 1.0.7, 1.0.8, 1.1.0, 1.1.1, 1.1.2, 1.2.0, 1.2.1, 1.2.2, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.0.4, 2.0.5, 2.0.6, 2.0.7, 2.0.8, 2.0.9, 2.1.0, 2.1.1, 2.1.2, 2.1.3, 2.1.4, 2.1.5, 2.1.6, 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.2.4, 2.2.5, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.4.2, 2.4.3, 2.5.0rc0, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0rc3, 2.6.0, 2.7.0rc0, 2.7.0rc2, 2.7.0, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.10.0rc0, 2.10.0rc1, 2.10.0, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0rc3, 2.11.0, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.13.1rc0, 2.13.1rc1, 2.13.1)
# ERROR: No matching distribution found for keras==2.5
# Segmentation Models: using `tf.keras` framework.

# %%
# this function creates the segmentation model by adding a dropout layer before the output softmax layer.
# different backbones can be used. num_classes is the number of classes to segment. One can change the input patch size as well.
# model_dp is the segmentation model to train. preprocess_input is the preprocessing input for the input patches to the model. In case of InceptionV3 this function
# rescales the input patches from [0,256] to [-1,1].

import tensorflow
import segmentation_models as sm
sm.set_framework('tf.keras')

BACKBONE = 'inceptionv3'
activation='softmax'
encoder_freeze = False
num_classes = 3

preprocess_input = sm.get_preprocessing(BACKBONE)
def model(dropout_value):
    preprocess_input = sm.get_preprocessing(BACKBONE)
    model = sm.Unet(BACKBONE,
                    input_shape = (256,256,3),
                    encoder_weights='imagenet',
                    classes=num_classes,
                    activation=activation,
                    encoder_freeze = encoder_freeze)
    model.summary()
    model_input = model.input
    model_output = model.get_layer('final_conv').output
    model_output = tensorflow.keras.layers.Dropout(dropout_value)(model_output)
    output = tensorflow.keras.layers.Activation(activation, name=activation)(model_output)
    model_dp = tensorflow.keras.models.Model(model_input, output)
    return model_dp, preprocess_input

# %% [markdown]
# #Modelling

# %%
########## Extracting Patches from images and masks ########
########## Extracting Patches from images and masks ########
########## Extracting Patches from images and masks ########

# temporairly changing mask values of 0 to 3 for patch extraction


#from crop_img_msk import crop_img_msk
patches = []
patches_masks = []
for i in range(len(images)):
    img_cropped,msk_cropped = crop_img_msk(images[i], masks[i], size = 256, stride = 128)
    for j in img_cropped:
        patches.append(j)
    for j in msk_cropped:
        patches_masks.append(j)
del img_cropped,msk_cropped,i,j

# %%
################## Shuffling Patches #######################
################## Shuffling Patches #######################
################## Shuffling Patches #######################
idx = np.random.RandomState(seed=42).permutation(np.arange(0,len(patches)))
patches = [patches[i] for i in idx]
patches_masks = [patches_masks[i] for i in idx]
del idx

################## Augmenting Patches #######################
################## Augmenting Patches #######################
################## Augmenting Patches #######################
#from aug_imgs_msks_d4 import aug_imgs_msks_d4
patches, patches_masks = aug_imgs_msks_d4(patches,patches_masks)

# %%
import matplotlib.pyplot as plt
import cv2

img = patches[31]
ann = patches_masks[31]

# Normalize the mask to the range [0, 255]
ann_normalized = cv2.normalize(ann, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)

# Apply a color map to the normalized mask
ann_colormap = cv2.applyColorMap(ann_normalized, cv2.COLORMAP_JET)

# Combine the original image and the colorized mask using alpha blending
overlay = cv2.addWeighted(img, 0.7, ann_colormap, 0.3, 0)

# Create a subplot grid with two columns
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Display the original image in the first subplot
axs[0].imshow(img)
axs[0].set_title('Original Image')

# Display the overlay in the second subplot
axs[1].imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
axs[1].set_title('Overlay')

# Remove the axis labels
for ax in axs:
    ax.axis('off')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
########################## Training Seg Model ##########################
########################## Training Seg Model ##########################
########################## Training Seg Model ##########################
from tensorflow.keras.utils import to_categorical
def image_mask_generator(imgs, msks, batch_size):
    L = len(imgs)
    while True:
        batch_start = 0
        batch_end = batch_size
        while batch_start < L:
            limit = min(batch_end, L)
            temp_imgs = []
            temp_msks = []
            for i in range(batch_start, limit):
                temp_imgs.append(imgs[i])
                temp_msks.append(msks[i])
            temp_imgs = [preprocess_input(i) for i in temp_imgs]
            temp_msks = [to_categorical(i, num_classes=3) for i in temp_msks]
            temp_imgs = np.array(temp_imgs)
            temp_msks = np.array(temp_msks)
            temp_msks = temp_msks[:, :, :, 2]  # Extract the second channel (index 1) from the label masks
            temp_msks = np.expand_dims(temp_msks, axis=-1)  # Add a single channel dimension
            yield (temp_imgs, temp_msks)  # a tuple with two numpy arrays with batch_size samples
            batch_start += batch_size
            batch_end += batch_size


import os
import random
import tensorflow
import segmentation_models as sm
#from segmentation_model import model
model, preprocess_input = model(dropout_value=0.4)



#class_weights = np.array([1.6, 1, 0.76])
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)
metrics = sm.metrics.IOUScore()
model.compile(tensorflow.keras.optimizers.Adam(learning_rate=0.0001), total_loss, metrics=metrics)

epochs = 10
batch_size = 32
os.environ['PYTHONHASHSEED'] = str(12321)
random.seed(12321)
np.random.seed(12321)
tensorflow.random.set_seed(12321)
filepath = "/content/drive/MyDrive/inceptionv3_TUMORRRRR_CHANNEL_all_{epoch:02d}.hdf5"
my_callbacks = [
    tensorflow.keras.callbacks.ModelCheckpoint(filepath, verbose=0, save_best_only=False, save_weights_only = True)
    ]

model.fit(image_mask_generator(patches, patches_masks, batch_size),
          epochs = epochs,
          steps_per_epoch = len(patches)//batch_size,
          verbose = 1,
          callbacks = my_callbacks)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_188 (Conv2D)            (None, 128, 128, 32  864         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_188 (Batch  (None, 128, 128, 32  96         ['conv2d_188[0][0]']
#  Normalization)                 )
#
#  activation_188 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_188[0][0]']
#                                 )
#
#  conv2d_189 (Conv2D)            (None, 128, 128, 32  9216        ['activation_188[0][0]']
#                                 )
#
#  batch_normalization_189 (Batch  (None, 128, 128, 32  96         ['conv2d_189[0][0]']
#  Normalization)                 )
#
#  activation_189 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_189[0][0]']
#                                 )
#
#  conv2d_190 (Conv2D)            (None, 128, 128, 64  18432       ['activation_189[0][0]']
#                                 )
#
#  batch_normalization_190 (Batch  (None, 128, 128, 64  192        ['conv2d_190[0][0]']
#  Normalization)                 )
#
#  activation_190 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_190[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 64)  0           ['activation_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 64, 64, 80)   5120        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_191 (Batch  (None, 64, 64, 80)  240         ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 64, 64, 80)   0           ['batch_normalization_191[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 64, 64, 192)  138240      ['activation_191[0][0]']
#
#  batch_normalization_192 (Batch  (None, 64, 64, 192)  576        ['conv2d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 64, 64, 192)  0           ['batch_normalization_192[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 192)  0          ['activation_192[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 32, 32, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_196 (Batch  (None, 32, 32, 64)  192         ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_196[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 32, 32, 48)   9216        ['max_pooling2d_9[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 32, 32, 96)   55296       ['activation_196[0][0]']
#
#  batch_normalization_194 (Batch  (None, 32, 32, 48)  144         ['conv2d_194[0][0]']
#  Normalization)
#
#  batch_normalization_197 (Batch  (None, 32, 32, 96)  288         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_194[0][0]']
#
#  activation_197 (Activation)    (None, 32, 32, 96)   0           ['batch_normalization_197[0][0]']
#
#  average_pooling2d_18 (AverageP  (None, 32, 32, 192)  0          ['max_pooling2d_9[0][0]']
#  ooling2D)
#
#  conv2d_193 (Conv2D)            (None, 32, 32, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 32, 32, 64)   76800       ['activation_194[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 32, 32, 96)   82944       ['activation_197[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 32, 32, 32)   6144        ['average_pooling2d_18[0][0]']
#
#  batch_normalization_193 (Batch  (None, 32, 32, 64)  192         ['conv2d_193[0][0]']
#  Normalization)
#
#  batch_normalization_195 (Batch  (None, 32, 32, 64)  192         ['conv2d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 32, 32, 96)  288         ['conv2d_198[0][0]']
#  Normalization)
#
#  batch_normalization_199 (Batch  (None, 32, 32, 32)  96          ['conv2d_199[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_193[0][0]']
#
#  activation_195 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 32, 32, 96)   0           ['batch_normalization_198[0][0]']
#
#  activation_199 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_199[0][0]']
#
#  mixed0 (Concatenate)           (None, 32, 32, 256)  0           ['activation_193[0][0]',
#                                                                   'activation_195[0][0]',
#                                                                   'activation_198[0][0]',
#                                                                   'activation_199[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 32, 32, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_203 (Batch  (None, 32, 32, 64)  192         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_203[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 32, 32, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 32, 32, 96)   55296       ['activation_203[0][0]']
#
#  batch_normalization_201 (Batch  (None, 32, 32, 48)  144         ['conv2d_201[0][0]']
#  Normalization)
#
#  batch_normalization_204 (Batch  (None, 32, 32, 96)  288         ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_201[0][0]']
#
#  activation_204 (Activation)    (None, 32, 32, 96)   0           ['batch_normalization_204[0][0]']
#
#  average_pooling2d_19 (AverageP  (None, 32, 32, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_200 (Conv2D)            (None, 32, 32, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 32, 32, 64)   76800       ['activation_201[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 32, 32, 96)   82944       ['activation_204[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 32, 32, 64)   16384       ['average_pooling2d_19[0][0]']
#
#  batch_normalization_200 (Batch  (None, 32, 32, 64)  192         ['conv2d_200[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 32, 32, 64)  192         ['conv2d_202[0][0]']
#  Normalization)
#
#  batch_normalization_205 (Batch  (None, 32, 32, 96)  288         ['conv2d_205[0][0]']
#  Normalization)
#
#  batch_normalization_206 (Batch  (None, 32, 32, 64)  192         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_200[0][0]']
#
#  activation_202 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_202[0][0]']
#
#  activation_205 (Activation)    (None, 32, 32, 96)   0           ['batch_normalization_205[0][0]']
#
#  activation_206 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_206[0][0]']
#
#  mixed1 (Concatenate)           (None, 32, 32, 288)  0           ['activation_200[0][0]',
#                                                                   'activation_202[0][0]',
#                                                                   'activation_205[0][0]',
#                                                                   'activation_206[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 32, 32, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_210 (Batch  (None, 32, 32, 64)  192         ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_210[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 32, 32, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 32, 32, 96)   55296       ['activation_210[0][0]']
#
#  batch_normalization_208 (Batch  (None, 32, 32, 48)  144         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_211 (Batch  (None, 32, 32, 96)  288         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 32, 32, 48)   0           ['batch_normalization_208[0][0]']
#
#  activation_211 (Activation)    (None, 32, 32, 96)   0           ['batch_normalization_211[0][0]']
#
#  average_pooling2d_20 (AverageP  (None, 32, 32, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_207 (Conv2D)            (None, 32, 32, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 32, 32, 64)   76800       ['activation_208[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 32, 32, 96)   82944       ['activation_211[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 32, 32, 64)   18432       ['average_pooling2d_20[0][0]']
#
#  batch_normalization_207 (Batch  (None, 32, 32, 64)  192         ['conv2d_207[0][0]']
#  Normalization)
#
#  batch_normalization_209 (Batch  (None, 32, 32, 64)  192         ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 32, 32, 96)  288         ['conv2d_212[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 32, 32, 64)  192         ['conv2d_213[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_207[0][0]']
#
#  activation_209 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 32, 32, 96)   0           ['batch_normalization_212[0][0]']
#
#  activation_213 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_213[0][0]']
#
#  mixed2 (Concatenate)           (None, 32, 32, 288)  0           ['activation_207[0][0]',
#                                                                   'activation_209[0][0]',
#                                                                   'activation_212[0][0]',
#                                                                   'activation_213[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 32, 32, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_215 (Batch  (None, 32, 32, 64)  192         ['conv2d_215[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_215[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 32, 32, 96)   55296       ['activation_215[0][0]']
#
#  batch_normalization_216 (Batch  (None, 32, 32, 96)  288         ['conv2d_216[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 32, 32, 96)   0           ['batch_normalization_216[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 16, 16, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_216[0][0]']
#
#  batch_normalization_214 (Batch  (None, 16, 16, 384)  1152       ['conv2d_214[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 16, 16, 96)  288         ['conv2d_217[0][0]']
#  Normalization)
#
#  activation_214 (Activation)    (None, 16, 16, 384)  0           ['batch_normalization_214[0][0]']
#
#  activation_217 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_217[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 16, 16, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 16, 16, 768)  0           ['activation_214[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'max_pooling2d_10[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 16, 16, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_222 (Batch  (None, 16, 16, 128)  384        ['conv2d_222[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_222[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 16, 16, 128)  114688      ['activation_222[0][0]']
#
#  batch_normalization_223 (Batch  (None, 16, 16, 128)  384        ['conv2d_223[0][0]']
#  Normalization)
#
#  activation_223 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_223[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 16, 16, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 16, 16, 128)  114688      ['activation_223[0][0]']
#
#  batch_normalization_219 (Batch  (None, 16, 16, 128)  384        ['conv2d_219[0][0]']
#  Normalization)
#
#  batch_normalization_224 (Batch  (None, 16, 16, 128)  384        ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_219[0][0]']
#
#  activation_224 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_224[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 16, 16, 128)  114688      ['activation_219[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 16, 16, 128)  114688      ['activation_224[0][0]']
#
#  batch_normalization_220 (Batch  (None, 16, 16, 128)  384        ['conv2d_220[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 16, 16, 128)  384        ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_220 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_220[0][0]']
#
#  activation_225 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_225[0][0]']
#
#  average_pooling2d_21 (AverageP  (None, 16, 16, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_218 (Conv2D)            (None, 16, 16, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 16, 16, 192)  172032      ['activation_220[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 16, 16, 192)  172032      ['activation_225[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 16, 16, 192)  147456      ['average_pooling2d_21[0][0]']
#
#  batch_normalization_218 (Batch  (None, 16, 16, 192)  576        ['conv2d_218[0][0]']
#  Normalization)
#
#  batch_normalization_221 (Batch  (None, 16, 16, 192)  576        ['conv2d_221[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 16, 16, 192)  576        ['conv2d_226[0][0]']
#  Normalization)
#
#  batch_normalization_227 (Batch  (None, 16, 16, 192)  576        ['conv2d_227[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_218[0][0]']
#
#  activation_221 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_221[0][0]']
#
#  activation_226 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_226[0][0]']
#
#  activation_227 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_227[0][0]']
#
#  mixed4 (Concatenate)           (None, 16, 16, 768)  0           ['activation_218[0][0]',
#                                                                   'activation_221[0][0]',
#                                                                   'activation_226[0][0]',
#                                                                   'activation_227[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 16, 16, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_232 (Batch  (None, 16, 16, 160)  480        ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_232 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_232[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 16, 16, 160)  179200      ['activation_232[0][0]']
#
#  batch_normalization_233 (Batch  (None, 16, 16, 160)  480        ['conv2d_233[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_233[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 16, 16, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 16, 16, 160)  179200      ['activation_233[0][0]']
#
#  batch_normalization_229 (Batch  (None, 16, 16, 160)  480        ['conv2d_229[0][0]']
#  Normalization)
#
#  batch_normalization_234 (Batch  (None, 16, 16, 160)  480        ['conv2d_234[0][0]']
#  Normalization)
#
#  activation_229 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_229[0][0]']
#
#  activation_234 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_234[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 16, 16, 160)  179200      ['activation_229[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 16, 16, 160)  179200      ['activation_234[0][0]']
#
#  batch_normalization_230 (Batch  (None, 16, 16, 160)  480        ['conv2d_230[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 16, 16, 160)  480        ['conv2d_235[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_230[0][0]']
#
#  activation_235 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_235[0][0]']
#
#  average_pooling2d_22 (AverageP  (None, 16, 16, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_228 (Conv2D)            (None, 16, 16, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 16, 16, 192)  215040      ['activation_230[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 16, 16, 192)  215040      ['activation_235[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 16, 16, 192)  147456      ['average_pooling2d_22[0][0]']
#
#  batch_normalization_228 (Batch  (None, 16, 16, 192)  576        ['conv2d_228[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 16, 16, 192)  576        ['conv2d_231[0][0]']
#  Normalization)
#
#  batch_normalization_236 (Batch  (None, 16, 16, 192)  576        ['conv2d_236[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 16, 16, 192)  576        ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_231[0][0]']
#
#  activation_236 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_236[0][0]']
#
#  activation_237 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_237[0][0]']
#
#  mixed5 (Concatenate)           (None, 16, 16, 768)  0           ['activation_228[0][0]',
#                                                                   'activation_231[0][0]',
#                                                                   'activation_236[0][0]',
#                                                                   'activation_237[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 16, 16, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_242 (Batch  (None, 16, 16, 160)  480        ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_242[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 16, 16, 160)  179200      ['activation_242[0][0]']
#
#  batch_normalization_243 (Batch  (None, 16, 16, 160)  480        ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_243[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 16, 16, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 16, 16, 160)  179200      ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 16, 16, 160)  480        ['conv2d_239[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 16, 16, 160)  480        ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_239[0][0]']
#
#  activation_244 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_244[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 16, 16, 160)  179200      ['activation_239[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 16, 16, 160)  179200      ['activation_244[0][0]']
#
#  batch_normalization_240 (Batch  (None, 16, 16, 160)  480        ['conv2d_240[0][0]']
#  Normalization)
#
#  batch_normalization_245 (Batch  (None, 16, 16, 160)  480        ['conv2d_245[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_240[0][0]']
#
#  activation_245 (Activation)    (None, 16, 16, 160)  0           ['batch_normalization_245[0][0]']
#
#  average_pooling2d_23 (AverageP  (None, 16, 16, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_238 (Conv2D)            (None, 16, 16, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 16, 16, 192)  215040      ['activation_240[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 16, 16, 192)  215040      ['activation_245[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 16, 16, 192)  147456      ['average_pooling2d_23[0][0]']
#
#  batch_normalization_238 (Batch  (None, 16, 16, 192)  576        ['conv2d_238[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 16, 16, 192)  576        ['conv2d_241[0][0]']
#  Normalization)
#
#  batch_normalization_246 (Batch  (None, 16, 16, 192)  576        ['conv2d_246[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 16, 16, 192)  576        ['conv2d_247[0][0]']
#  Normalization)
#
#  activation_238 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_238[0][0]']
#
#  activation_241 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_241[0][0]']
#
#  activation_246 (Activation)    (None, 16, 16, 192)  0           ['batch_normalization_246[0][0]']
#
# ...
#  batch_normalization_280 (Batch  (None, 8, 8, 384)   1152        ['conv2d_280[0][0]']
#  Normalization)
#
#  conv2d_281 (Conv2D)            (None, 8, 8, 192)    393216      ['average_pooling2d_26[0][0]']
#
#  batch_normalization_273 (Batch  (None, 8, 8, 320)   960         ['conv2d_273[0][0]']
#  Normalization)
#
#  activation_275 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_275[0][0]']
#
#  activation_276 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_276[0][0]']
#
#  activation_279 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_279[0][0]']
#
#  activation_280 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_280[0][0]']
#
#  batch_normalization_281 (Batch  (None, 8, 8, 192)   576         ['conv2d_281[0][0]']
#  Normalization)
#
#  activation_273 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_273[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_275[0][0]',
#                                                                   'activation_276[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 8, 8, 768)    0           ['activation_279[0][0]',
#                                                                   'activation_280[0][0]']
#
#  activation_281 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_281[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_273[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'activation_281[0][0]']
#
#  decoder_stage0_upsampling (UpS  (None, 16, 16, 2048  0          ['mixed10[0][0]']
#  ampling2D)                     )
#
#  decoder_stage0_concat (Concate  (None, 16, 16, 2816  0          ['decoder_stage0_upsampling[0][0]
#  nate)                          )                                ',
#                                                                   'mixed7[0][0]']
#
#  decoder_stage0a_conv (Conv2D)  (None, 16, 16, 256)  6488064     ['decoder_stage0_concat[0][0]']
#
#  decoder_stage0a_bn (BatchNorma  (None, 16, 16, 256)  1024       ['decoder_stage0a_conv[0][0]']
#  lization)
#
#  decoder_stage0a_relu (Activati  (None, 16, 16, 256)  0          ['decoder_stage0a_bn[0][0]']
#  on)
#
#  decoder_stage0b_conv (Conv2D)  (None, 16, 16, 256)  589824      ['decoder_stage0a_relu[0][0]']
#
#  decoder_stage0b_bn (BatchNorma  (None, 16, 16, 256)  1024       ['decoder_stage0b_conv[0][0]']
#  lization)
#
#  decoder_stage0b_relu (Activati  (None, 16, 16, 256)  0          ['decoder_stage0b_bn[0][0]']
#  on)
#
#  decoder_stage1_upsampling (UpS  (None, 32, 32, 256)  0          ['decoder_stage0b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage1_concat (Concate  (None, 32, 32, 544)  0          ['decoder_stage1_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'mixed2[0][0]']
#
#  decoder_stage1a_conv (Conv2D)  (None, 32, 32, 128)  626688      ['decoder_stage1_concat[0][0]']
#
#  decoder_stage1a_bn (BatchNorma  (None, 32, 32, 128)  512        ['decoder_stage1a_conv[0][0]']
#  lization)
#
#  decoder_stage1a_relu (Activati  (None, 32, 32, 128)  0          ['decoder_stage1a_bn[0][0]']
#  on)
#
#  decoder_stage1b_conv (Conv2D)  (None, 32, 32, 128)  147456      ['decoder_stage1a_relu[0][0]']
#
#  decoder_stage1b_bn (BatchNorma  (None, 32, 32, 128)  512        ['decoder_stage1b_conv[0][0]']
#  lization)
#
#  decoder_stage1b_relu (Activati  (None, 32, 32, 128)  0          ['decoder_stage1b_bn[0][0]']
#  on)
#
#  decoder_stage2_upsampling (UpS  (None, 64, 64, 128)  0          ['decoder_stage1b_relu[0][0]']
#  ampling2D)
#
#  decoder_stage2_concat (Concate  (None, 64, 64, 320)  0          ['decoder_stage2_upsampling[0][0]
#  nate)                                                           ',
#                                                                   'activation_192[0][0]']
#
#  decoder_stage2a_conv (Conv2D)  (None, 64, 64, 64)   184320      ['decoder_stage2_concat[0][0]']
#
#  decoder_stage2a_bn (BatchNorma  (None, 64, 64, 64)  256         ['decoder_stage2a_conv[0][0]']
#  lization)
#
#  decoder_stage2a_relu (Activati  (None, 64, 64, 64)  0           ['decoder_stage2a_bn[0][0]']
#  on)
#
#  decoder_stage2b_conv (Conv2D)  (None, 64, 64, 64)   36864       ['decoder_stage2a_relu[0][0]']
#
#  decoder_stage2b_bn (BatchNorma  (None, 64, 64, 64)  256         ['decoder_stage2b_conv[0][0]']
#  lization)
#
#  decoder_stage2b_relu (Activati  (None, 64, 64, 64)  0           ['decoder_stage2b_bn[0][0]']
#  on)
#
#  decoder_stage3_upsampling (UpS  (None, 128, 128, 64  0          ['decoder_stage2b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage3_concat (Concate  (None, 128, 128, 12  0          ['decoder_stage3_upsampling[0][0]
#  nate)                          8)                               ',
#                                                                   'activation_190[0][0]']
#
#  decoder_stage3a_conv (Conv2D)  (None, 128, 128, 32  36864       ['decoder_stage3_concat[0][0]']
#                                 )
#
#  decoder_stage3a_bn (BatchNorma  (None, 128, 128, 32  128        ['decoder_stage3a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3a_relu (Activati  (None, 128, 128, 32  0          ['decoder_stage3a_bn[0][0]']
#  on)                            )
#
#  decoder_stage3b_conv (Conv2D)  (None, 128, 128, 32  9216        ['decoder_stage3a_relu[0][0]']
#                                 )
#
#  decoder_stage3b_bn (BatchNorma  (None, 128, 128, 32  128        ['decoder_stage3b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage3b_relu (Activati  (None, 128, 128, 32  0          ['decoder_stage3b_bn[0][0]']
#  on)                            )
#
#  decoder_stage4_upsampling (UpS  (None, 256, 256, 32  0          ['decoder_stage3b_relu[0][0]']
#  ampling2D)                     )
#
#  decoder_stage4a_conv (Conv2D)  (None, 256, 256, 16  4608        ['decoder_stage4_upsampling[0][0]
#                                 )                                ']
#
#  decoder_stage4a_bn (BatchNorma  (None, 256, 256, 16  64         ['decoder_stage4a_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4a_relu (Activati  (None, 256, 256, 16  0          ['decoder_stage4a_bn[0][0]']
#  on)                            )
#
#  decoder_stage4b_conv (Conv2D)  (None, 256, 256, 16  2304        ['decoder_stage4a_relu[0][0]']
#                                 )
#
#  decoder_stage4b_bn (BatchNorma  (None, 256, 256, 16  64         ['decoder_stage4b_conv[0][0]']
#  lization)                      )
#
#  decoder_stage4b_relu (Activati  (None, 256, 256, 16  0          ['decoder_stage4b_bn[0][0]']
#  on)                            )
#
#  final_conv (Conv2D)            (None, 256, 256, 3)  435         ['decoder_stage4b_relu[0][0]']
#
#  softmax (Activation)           (None, 256, 256, 3)  0           ['final_conv[0][0]']
#
# ==================================================================================================
# Total params: 29,933,395
# Trainable params: 29,896,979
# Non-trainable params: 36,416
# __________________________________________________________________________________________________
# Epoch 1/10
# 4900/4900 [==============================] - 3973s 802ms/step - loss: 0.4796 - iou_score: 0.4574
# Epoch 2/10
# 4900/4900 [==============================] - 3938s 804ms/step - loss: 0.4493 - iou_score: 0.4913
# Epoch 3/10
# 4900/4900 [==============================] - 3940s 804ms/step - loss: 0.4413 - iou_score: 0.5003
# Epoch 4/10
# 4900/4900 [==============================] - 3946s 805ms/step - loss: 0.4365 - iou_score: 0.5058
# Epoch 5/10
# 3327/4900 [===================>..........] - ETA: 21:01 - loss: 0.4332 - iou_score: 0.5096
